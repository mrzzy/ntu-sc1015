# %% [markdown]
# # Does the Category of the Business Affct whether it will remain open?

# %%
# Libraries
import pandas as pd
import seaborn as sb
sb.set_theme()
import re
import os
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
business = pd.read_json(path_or_buf="/content/drive/MyDrive/Colab Notebooks/yelp_academic_dataset_business.json", lines=True)

# %%
categories = business["categories"]

# %%
print(categories)
# Out:
# 0         Doctors, Traditional Chinese Medicine, Naturop...
# 1         Shipping Centers, Local Services, Notaries, Ma...
# 2         Department Stores, Shopping, Fashion, Home & G...
# 3         Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                                 Brewpubs, Breweries, Food
#                                 ...
# 150341                           Nail Salons, Beauty & Spas
# 150342    Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343    Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344    Fitness/Exercise Equipment, Eyewear & Optician...
# 150345    Beauty & Spas, Permanent Makeup, Piercing, Tattoo
# Name: categories, Length: 150346, dtype: object

# %% [markdown]
# Each business has multiple different categories tag

# %%
## Count the number of categories
category_set = set()
category_count = Counter()
for category in categories:
  split = str(category).split(",")
  for index, data in enumerate(split):
    if data[0] == " ":
      split[index] = split[index][1:]
  category_count.update(split)
  for data in split:
    category_set.add(data)

print(category_count)
# Out:
# Counter({'Restaurants': 52268, 'Food': 27781, 'Shopping': 24395, 'Home Services': 14356, 'Beauty & Spas': 14292, 'Nightlife': 12281, 'Health & Medical': 11890, 'Local Services': 11198, 'Bars': 11065, 'Automotive': 10773, 'Event Planning & Services': 9895, 'Sandwiches': 8366, 'American (Traditional)': 8139, 'Active Life': 7687, 'Pizza': 7093, 'Coffee & Tea': 6703, 'Fast Food': 6472, 'Breakfast & Brunch': 6239, 'American (New)': 6097, 'Hotels & Travel': 5857, 'Home & Garden': 5799, 'Fashion': 5739, 'Burgers': 5636, 'Arts & Entertainment': 5434, 'Auto Repair': 5433, 'Hair Salons': 5046, 'Nail Salons': 4621, 'Mexican': 4600, 'Italian': 4573, 'Specialty Food': 4233, 'Doctors': 3763, 'Pets': 3758, 'Real Estate': 3577, 'Seafood': 3539, 'Fitness & Instruction': 3293, 'Professional Services': 3270, 'Hair Removal': 3239, 'Desserts': 3186, 'Chinese': 3169, 'Bakeries': 3150, 'Grocery': 3139, 'Salad': 3064, 'Hotels': 2977, 'Chicken Wings': 2966, 'Cafes': 2756, 'Ice Cream & Frozen Yogurt': 2657, 'Caterers': 2645, 'Pet Services': 2626, 'Dentists': 2528, 'Skin Care': 2498, 'Venues & Event Spaces': 2480, 'Tires': 2471, 'Beer': 2413, 'Wine & Spirits': 2413, 'Delis': 2393, 'Oil Change Stations': 2356, 'Waxing': 2333, 'Contractors': 2327, "Women's Clothing": 2184, 'Massage': 2134, 'Sports Bars': 2110, 'Day Spas': 1997, 'General Dentistry': 1993, 'Education': 1936, 'Flowers & Gifts': 1930, 'Auto Parts & Supplies': 1926, 'Apartments': 1921, 'Convenience Stores': 1919, 'Home Decor': 1892, 'Gyms': 1831, 'Japanese': 1830, 'Pubs': 1821, 'Cocktail Bars': 1718, 'Sushi Bars': 1717, 'Barbeque': 1694, 'Juice Bars & Smoothies': 1684, 'Barbers': 1677, 'Car Dealers': 1665, 'Sporting Goods': 1662, 'Accessories': 1639, 'Cosmetic Dentists': 1630, 'Drugstores': 1630, 'Local Flavor': 1604, 'Furniture Stores': 1597, 'Pet Groomers': 1549, 'Asian Fusion': 1547, 'Cosmetics & Beauty Supply': 1544, 'Jewelry': 1525, 'Steakhouses': 1506, 'Diners': 1494, 'Financial Services': 1487, 'Trainers': 1460, 'Hair Stylists': 1459, 'Arts & Crafts': 1440, 'Department Stores': 1430, 'Electronics': 1422, 'Veterinarians': 1383, 'Massage Therapy': 1357, 'Pet Sitting': 1356, 'Eyelash Service': 1278, 'Food Trucks': 1273, "Men's Clothing": 1273, 'Mediterranean': 1263, 'Body Shops': 1229, 'Public Services & Government': 1216, 'Heating & Air Conditioning/HVAC': 1199, 'Lounges': 1194, 'Wine Bars': 1192, 'IT Services & Computer Repair': 1189, 'Vegetarian': 1158, 'Laundry Services': 1149, 'Medical Centers': 1131, 'Optometrists': 1112, 'Plumbing': 1111, 'Gas Stations': 1106, 'Music Venues': 1104, 'Donuts': 1097, 'Dry Cleaning & Laundry': 1075, 'Party & Event Planning': 1073, 'Soup': 1061, 'Food Delivery Services': 1050, 'Pet Stores': 1043, 'Tacos': 1020, 'Shoe Stores': 1018, 'Eyewear & Opticians': 1016, 'Southern': 988, 'Parks': 984, 'Books': 975, 'Mags': 975, 'Music & Video': 975, 'Makeup Artists': 973, 'Thai': 971, 'Car Wash': 960, 'Florists': 955, 'Building Supplies': 954, 'Mobile Phones': 952, 'Movers': 948, 'Yoga': 938, 'Specialty Schools': 932, 'Cajun/Creole': 923, 'Tex-Mex': 919, 'Auto Detailing': 906, 'Landscaping': 896, 'Nurseries & Gardening': 892, 'Appliances': 872, 'Beer Bar': 870, 'Discount Store': 868, 'Breweries': 863, 'Transportation': 858, 'Vegan': 856, 'Vietnamese': 852, 'Home Cleaning': 850, 'Tours': 842, 'Sewing & Alterations': 842, 'Indian': 838, "Men's Hair Salons": 828, 'Latin American': 810, 'Chicken Shop': 808, 'Appliances & Repair': 800, 'Real Estate Services': 800, 'Gift Shops': 796, 'Self Storage': 795, 'Shipping Centers': 792, 'Hardware Stores': 792, 'Printing Services': 790, 'Art Galleries': 786, 'Medical Spas': 781, 'Greek': 779, 'Gluten-Free': 777, 'Hot Dogs': 774, 'Kitchen & Bath': 763, 'Property Management': 759, 'Used': 753, 'Vintage & Consignment': 753, 'Oral Surgeons': 752, 'Banks & Credit Unions': 749, 'Comfort Food': 746, 'Bagels': 738, 'Auto Glass Services': 727, 'Chiropractors': 726, 'Wedding Planning': 709, 'Endodontists': 706, 'Towing': 692, 'Tobacco Shop ...

# %%
print("Total number of unique categories : ", len(category_set))
# Out:
# Total number of unique categories :  1312

# %%
wordcloud = WordCloud().generate_from_frequencies(category_count)

plt.figure(figsize=(15, 15))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
## K-Means Clustering
cluster = 20
kmeans = KMeans(n_clusters = cluster)
vectorizer = TfidfVectorizer()
category_feature = vectorizer.fit_transform(list(category_set))
kmeans.fit(category_feature)
cluster_labels = kmeans.labels_

new_cat = []
for x in range(cluster):
  new_cat.append([])

for category, label in zip(list(category_set), cluster_labels):
  new_cat[label].append(category)

for x in new_cat:
  print(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ['Funeral Services & Cemeteries', 'Piano Services', 'Valet Services', 'Holiday Decorating Services', 'Nanny Services', 'Financial Services', 'Aquarium Services', 'Music Production Services', 'Translation Services', 'Appraisal Services', 'Reproductive Health Services', 'Couriers & Delivery Services', 'Refinishing Services', 'Shredding Services', 'Fireplace Services', 'Adoption Services', 'Blow Dry/Out Services', 'Musical Instrument Services', 'Billing Services', 'Lactation Services', 'Public Services & Government', 'Grout Services', 'Printing Services', 'Passport & Visa Services', 'Legal Services', 'Stucco Services', 'Car Share Services', 'Educational Services', 'Packing Services', 'Portable Toilet Services', 'Pet Services', 'Backflow Services', 'Real Estate Services', 'Debt Relief Services', 'Balloon Services', 'Travel Services', 'Tax Services', 'Mortuary Services', 'Aviation Services', 'Grill Services', 'Crane Services', 'Pet Cremation Services', 'Excavation Services', 'Gutter Services', 'Payroll Services', 'Auto Glass Services', 'Lice Services', 'Mobility Equipment Sales & Services', 'Digitizing Services', 'Elevator Services', 'Eyebrow Services', 'Editorial Services', 'Demolition Services', 'Tree Services', 'Diagnostic Services', 'Duplication Services', 'Professional Services', 'Outdoor Power Equipment Services', 'Home Services', 'Registration Services', 'Septic Services', 'Lawn Services', 'Food Delivery Services', 'Laundry Services', 'Metal Detector Services', 'Cremation Services', 'Event Planning & Services', 'Fire Protection Services', 'Local Services', 'Water Purification Services', 'Threading Services', 'Security Services', 'Garage Door Services']
# ['Traditional Chinese Medicine', 'American (New)', 'American (Traditional)', 'Traditional Clothing', 'Latin American']
# ['Elementary Schools', 'Language Schools', 'Nursing Schools', 'Cooking Schools', 'Cosmetology Schools', 'Montessori Schools', 'Ski Schools', 'Circus Schools', 'Specialty Schools', 'Driving Schools', 'Middle Schools & High Schools', 'DUI Schools', 'Art Schools', 'Private Schools', 'Waldorf Schools', 'Bartending Schools', 'Religious Schools', 'Surf Schools', 'Drama Schools', 'Traffic Schools', 'Dance Schools', 'Swimming Lessons/Schools', 'Massage Schools']
# ['Caterers', 'Environmental Abatement', 'Recycling Center', 'Screen Printing/T-Shirt Printing', 'Used Bookstore', 'Orthopedists', 'Horse Boarding', 'Bistros', 'Rheumatologists', 'Videographers', 'Assisted Living Facilities', 'Mags', 'Ophthalmologists', 'Gas Stations', 'Fitness & Instruction', 'Airport Lounges', 'Scavenger Hunts', 'Izakaya', 'Challenge Courses', 'Disc Golf', 'Guns & Ammo', 'Tex-Mex', 'Phlebologists', 'Boot Camps', 'Outdoor Gear', 'Permanent Makeup', 'Bar Crawl', 'Car Wash', 'Ukrainian', 'Community Centers', 'Badminton', 'Brewing Supplies', 'Indian', 'Vegan', 'Surfing', 'Radiologists', 'Guest Houses', 'Szechuan', 'Auto Insurance', 'Go Karts', 'Sports Betting', 'Internet Service Providers', 'Hotel bar', 'Siding', 'Electronics', 'Wigs', 'Cucina campana', 'Art Restoration', 'Counseling & Mental Health', 'Weight Loss Centers', 'Well Drilling', 'Buffets', 'Polish', 'Sailing', 'Fashion', 'Gold Buyers', 'Reflexology', 'Eatertainment', 'Advertising', 'Rest Stops', 'Cardiologists', 'Mailbox Centers', 'Brewpubs', 'Tui Na', 'Vascular Medicine', 'Brazilian Jiu-jitsu', 'Wildlife Hunting Ranges', 'Public Relations', 'Psychics', 'Television Service Providers', 'Interval Training Gyms', 'Ticket Sales', 'Empanadas', 'Music Venues', 'Gardeners', 'Country Dance Halls', 'Cheerleading', 'Carpenters', 'Recording & Rehearsal Studios', 'Art Consultants', 'Oriental', 'Concierge Medicine', 'Karaoke', 'Flea Markets', 'Dance Studios', 'Botanical Gardens', 'Delicatessen', 'Junkyards', 'Martial Arts', 'Product Design', 'Olive Oil', 'Moroccan', 'Persian/Iranian', 'Honey', 'Bail Bondsmen', 'Ice Delivery', 'Osteopaths', 'Chicken Wings', 'Portuguese', 'Health Coach', 'Engraving', 'Ranches', 'Landmarks & Historical Buildings', 'Malaysian', 'Kiteboarding', 'Tubing', 'Ethnic Grocery', 'Pilates', 'High Fidelity Audio Equipment', 'Tai Chi', 'Boat Charters', 'Professional Sports Teams', 'Kickboxing', 'Donation Center', 'Bookstores', 'Jewelry', 'Soul Food', 'Free Diving', 'Parent Cafes', 'Furniture Assembly', 'Special Education', 'General Litigation', 'Basque', 'Surf Shop', 'Honduran', 'Hot Air Balloons', 'Climbing', 'Car Inspectors', 'Health Retreats', 'Trampoline Parks', 'Real Estate Photography', 'Lighting Fixtures & Equipment', 'Steakhouses', 'Prosthodontists', 'Poutineries', 'Banks & Credit Unions', 'Food Stands', 'Pancakes', 'Television Stations', 'Egyptian', 'Roman', 'Dog Parks', 'Public Art', 'Amateur Sports Teams', 'Coffee & Tea', 'Russian', 'Childbirth Education', 'Swimwear', 'Georgian', 'Sunglasses', 'Notaries', 'Circuit Training Gyms', 'Orthotics', 'Anesthesiologists', 'Fire Departments', 'Local Flavor', 'Live/Raw Food', 'None', 'Limos', 'Service Stations', 'Crisis Pregnancy Centers', 'Delis', 'Pediatricians', 'Buddhist Temples', 'Pick Your Own Farms', 'Clowns', 'Plumbing', 'Soccer', 'General Festivals', 'International', 'Pediatric Dentists', 'Beauty & Spas', 'Private Jet Charter', 'Dry Cleaning', 'Spanish', 'Farmers Market', 'Gemstones & Minerals', 'Races & Competitions', 'Artificial Turf', 'Otologists', 'Comic Books', 'Arcades', 'Towing', 'Cannabis Collective', 'Sports Psychologists', 'Dinner Theater', 'Modern European', 'Haunted Houses', 'Powder Coating', 'Carpet Dyeing', 'Obstetricians & Gynecologists', 'Piercing', 'Eastern European', 'Private Tutors', 'Session Photography', 'Fences & Gates', 'Health & Medical', 'Housing Cooperatives', 'Smokehouse', 'Sri Lankan', "Children's Clothing", 'Rehabilitation Center', 'Personal Assistants', 'Childproofing', 'Venezuelan', 'Hainan', 'Physical Therapy', 'Farming Equipment', 'Paragliding', 'Pet Transportation', 'Nephrologists', 'Bagels', 'Fuzhou', 'Smog Check Stations', 'Animal Shelters', 'French', 'Utilities', 'Karate', 'Burmese', 'Austrian', 'Uniforms', 'Tennis', 'Airlines', 'Fast Food', 'Accessories', 'Land Surveying', 'Falafel', 'Wills', 'Adult', 'Attraction Farms', 'Chiropractors', 'Supernatural Readings', 'Fishing', 'Flooring', 'Glass & Mirrors', 'Hang Gliding', 'Ziplining', 'Pet Insurance',  ...
# ['Outdoor Furniture Stores', 'Hardware Stores', 'Local Fish Stores', 'Thrift Stores', 'Water Stores', 'Department Stores', 'Candle Stores', 'Piano Stores', 'Lighting Stores', 'Outlet Stores', 'Pet Stores', 'Photography Stores & Services', 'Shoe Stores', 'Video Game Stores', 'Safe Stores', 'Guitar Stores', 'Toy Stores', 'Fabric Stores', 'Paint Stores', 'Furniture Stores', 'Organic Stores', 'Convenience Stores', 'Candy Stores', 'Wholesale Stores', 'Battery Stores']
# ['Mobile Phone Repair', 'Mobile Home Repair', 'Mobile Phone Accessories', 'Mobile Dent Repair', 'Mobile Phones', 'Mobile Home Parks', 'Mobile Home Dealers']
# ['Aircraft Dealers', 'Car Dealers', 'Vehicle Shipping', 'Golf Cart Dealers', 'Motorsport Vehicle Repairs', 'Motorsport Vehicle Dealers', 'Vehicle Wraps', 'Used Car Dealers', 'RV Dealers', 'Trailer Dealers', 'Boat Dealers', 'Commercial Truck Dealers', 'Motorcycle Dealers']
# ['Cheese Tasting Classes', 'First Aid Classes', 'Art Classes', 'Parenting Classes', 'Cardio Classes', 'Pole Dancing Classes', 'Barre Classes', 'Wine Tasting Classes', 'Self-defense Classes', 'Photography Classes', 'Spin Classes', 'Cooking Classes', 'Cycling Classes', 'CPR Classes', 'Tasting Classes']
# ['Country Clubs', 'Comedy Clubs', 'Dance Clubs', 'Strip Clubs', 'Social Clubs', 'Supper Clubs', 'Fencing Clubs', 'Sports Clubs']
# ['Cannabis Tours', 'Beer Tours', 'Art Tours', 'Walking Tours', 'Historical Tours', 'Wine Tours', 'ATV Rentals/Tours', 'Tours', 'Whale Watching Tours', 'Bike tours', 'Aerial Tours', 'Architectural Tours', 'Bus Tours', 'Food Tours', 'Boat Tours', 'Scooter Tours']
# ['Urgent Care', 'Holistic Animal Care', 'Skin Care', 'Elder Care Planning', 'Child Care & Day Care', 'Prenatal/Perinatal Care', 'Memory Care', 'Home Health Care', 'Foot Care', 'Personal Care Services']
# ['Drive-In Theater', 'Dialysis Clinics', 'Storefront Clinics', 'Cannabis Clinics', 'Walk-in Clinics']
# ['Party Equipment Rentals', 'Vacation Rentals', 'Bike Shop', 'Party & Event Planning', 'Bike Rentals', 'Party Bus Rentals', 'Photo Booth Rentals', 'Party Characters', 'Bounce House Rentals', 'Bike Parking', 'Golf Cart Rentals', 'Party Supplies', 'Bike Sharing', 'Art Space Rentals', 'Beach Equipment Rentals', 'Scooter Rentals', 'Party Bike Rentals']
# ['Appliances & Repair', 'Wheel & Rim Repair', 'Jewelry Repair', 'RV Repair', 'Boat Repair', 'Transmission Repair', 'Auto Repair', 'Farm Equipment Repair', 'Commercial Truck Repair', 'Shoe Repair', 'Hybrid Car Repair', 'IT Services & Computer Repair', 'Trailer Repair', 'Motorcycle Repair', 'Electronics Repair', 'Foundation Repair', 'Bike Repair', 'Watch Repair', 'Furniture Repair', 'Clock Repair', 'Bike Repair/Maintenance']
# ['Vermouth Bars', 'Gay Bars', 'Whiskey Bars', 'Cigar Bars', 'Champagne Bars', 'Bars', 'Wine Bars', 'Drive-Thru Bars', 'Oxygen Bars', 'Tapas Bars', 'Sports Bars', 'Beach Bars', 'Juice Bars & Smoothies', 'Dive Bars', 'Cocktail Bars', 'Piano Bars', 'Sushi Bars', 'Tiki Bars', 'Hookah Bars']
# ['Business Law', 'Disability Law', 'Social Security Law', 'IP & Internet Law', 'Traffic Ticketing Law', 'Contract Law', 'Elder Law', 'Personal Injury Law', 'Estate Planning Law', 'Real Estate Law', 'Divorce & Family Law', 'Consumer Law', 'Patent Law', 'Bankruptcy Law', 'Medical Law', 'DUI Law', 'Employment Law', 'Tenant and Eviction Law', 'Tax Law', 'Workers Compensation Law', 'Immigration Law', 'Criminal Defense Law']
# ['Car Stereo Installation', 'Countertop Installation', 'Carpet Installation', 'Sauna Installation & Repair', 'Water Heater Installation/Repair', 'Door Sales/Installation', 'Windows Installation', 'Solar Installation', 'Drywall Installation & Repair', 'Windshield Installation & Repair', 'Generator Installation/Repair', 'Art Installation', 'Home Network Installation', 'Home Theatre Installation', 'Insulation Installation']
# ['Dance Wear', 'Formal Wear', 'Maternity Wear', 'Sports Wear']
# ['Ski & Snowboard Shops', 'Trophy Shops', 'Tobacco Shops', 'Pop-up Shops', 'Pasta Shops', 'Vape Shops', 'Popcorn Shops', 'Reptile Shops', 'Golf Equipment Shops', 'Bird Shops', 'Horse Equipment Shops', 'Dive Shops', 'Herbal Shops', 'Cheese Shops', 'Pawn Shops', 'Skate Shops', 'Hobby Shops', 'Head Shops', 'Concept Shops', 'Gift Shops', 'Meat Shops', 'Souvenir Shops', 'Machine Shops', 'Body Shops', 'Chocolatiers & Shops']
# ['Motorcycle Rental', 'Trailer Rental', 'RV Rental', 'Dumpster Rental', 'Clothing Rental', 'Karaoke Rental', 'Car Rental', 'Furniture Rental', 'Machine & Tool Rental', 'Bus Rental', 'Game Truck Rental', 'Videos & Video Game Rental', 'Vacation Rental Agents', 'Audio/Visual Equipment Rental', 'Home & Rental Insurance', 'Truck Rental']

# %% [markdown]
# It manage to cluster some categories, however there were some clusters that were still not clustered well and any remaining of the categories that wasn't able to be clustered are clustered into one. Overall, it was still hard to extract out main categories for our analysis so we decided to search online for possible yelp main categories.
#
# We decided to check up on the yelp dataset category list online to see if there are any generalize main categories. [Yelp Dataset Categories](https://blog.yelp.com/businesses/yelp_category_list/). Surely enough they did separate the business categories into  `main categories` and each of them had `sub categories`. Therefore we decided to use the `main categories` provided in the site for our generalization.

# %%
## Using based on yelp dataset main categories

category_list = ["Active Life", "Arts & Entertainment", "Automotive", "Beauty & Spas", "Education", "Event Planning & Services", "Financial Services", "Food", "Health & Medical", "Home Services", "Hotels & Travel", "Local Flavor", "Local Services",  "Mass Media", "Nightlife", "Pets", "Professional Services", "Public Services & Government", "Religious Organizations", "Restaurants", "Shopping", "Others"]

# %% [markdown]
# ------------------
#
# ## Business Category Explanation
#
# `Restaurants` is categorized to businesses where you can sit down and have a meal, typically with table service or a counter where you can order your foods.
#
# `Food` is categorized as businesses that sell food items, but not necessarily in a sit-down dining format.
#
# ------------------

# %%
test = business.copy(deep=False)
test = test.iloc[0:0]

category_df = []
category_count = []
for category in category_list:
  category_df.append(test.copy())
  category_count.append(0)

# %%
# Exporting the different business categories into individual dataframe

for index, x in enumerate(categories):
  status = False
  ilocdata = business.iloc[index]
  if not x:
    category_df[-1].loc[category_count[-1]] = ilocdata
    category_count[-1] += 1
    status = True

  for category_index, category in enumerate(category_list):
    if x is None:
      break
    if category in x:
      category_df[category_index].loc[category_count[category_index]] = ilocdata
      category_count[category_index] += 1
      status = True
  if not status:
    category_df[-1].loc[category_count[-1]] = ilocdata
    category_count[-1] += 1

# %%
# Exporting the dataframes into csv files
for index, dataframe in enumerate(category_df):
  path = ("/content/drive/MyDrive/Colab Notebooks/New Export/" + category_list[index] + ".csv")
  print(path)
  dataframe.to_csv(path_or_buf=path)
# Out:
# /content/drive/MyDrive/Colab Notebooks/New Export/Active Life.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Arts & Entertainment.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Automotive.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Beauty & Spas.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Education.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Event Planning & Services.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Financial Services.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Food.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Health & Medical.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Home Services.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Hotels & Travel.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Local Flavor.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Local Services.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Mass Media.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Nightlife.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Pets.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Professional Services.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Public Services & Government.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Religious Organizations.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Restaurants.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Shopping.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Others.csv

# %% [markdown]
# # Continue from after category seperation

# %%
export_dir = "/content/drive/MyDrive/Colab Notebooks/New Export"

# csv_list = os.listdir(export_dir)
# csv_list = sorted(csv_list)
# print(csv_list)
new_category_df = []
for csv_name in category_list:
  csv_name = csv_name + ".csv"
  csv_path = os.path.join(export_dir, csv_name)
  print(csv_path)
  new_category_df.append(pd.read_csv(csv_path))
# Out:
# /content/drive/MyDrive/Colab Notebooks/New Export/Active Life.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Arts & Entertainment.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Automotive.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Beauty & Spas.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Education.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Event Planning & Services.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Financial Services.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Food.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Health & Medical.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Home Services.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Hotels & Travel.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Local Flavor.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Local Services.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Mass Media.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Nightlife.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Pets.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Professional Services.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Public Services & Government.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Religious Organizations.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Restaurants.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Shopping.csv
# /content/drive/MyDrive/Colab Notebooks/New Export/Others.csv

# %%
new_category_df[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7954 entries, 0 to 7953
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    7954 non-null   int64
#  1   business_id   7954 non-null   object
#  2   name          7954 non-null   object
#  3   address       7741 non-null   object
#  4   city          7954 non-null   object
#  5   state         7954 non-null   object
#  6   postal_code   7950 non-null   object
#  7   latitude      7954 non-null   float64
#  8   longitude     7954 non-null   float64
#  9   stars         7954 non-null   float64
#  10  review_count  7954 non-null   int64
#  11  is_open       7954 non-null   int64
#  12  attributes    7637 non-null   object
#  13  categories    7954 non-null   object
#  14  hours         6283 non-null   object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 932.2+ KB

# %%
test_df = pd.DataFrame([len(df.index) for df in new_category_df])
test_df.index = category_list

ax = test_df.plot(kind="bar", stacked = False)

for container in ax.containers:
  ax.bar_label(container)

plt.gcf().set_size_inches(30, 10)
plt.xlabel("Categories")
plt.ylabel("Count")
plt.title("Counts of business")
plt.show()

# %% [markdown]
# We first analyze the count for each main categories. We can clearly see that `Restaurants` has the highest number of business open of a count of `53886` and followed by `Food` with a count of `3444` business open. Next we can see that `Mass Media`, `Religious Organizations` and `Others` category has the lowest number of business open of less than `300`. We can clearly see which business is the most popular and which business is the least popular.

# %%
def count_open_closed(df):
  return df["is_open"].value_counts()

test_df = pd.DataFrame([count_open_closed(df) for df in new_category_df])
test_df.index = category_list

ax = test_df.plot(kind="bar", stacked = False)

for container in ax.containers:
  ax.bar_label(container)

plt.gcf().set_size_inches(30, 10)
plt.xlabel("Categories")
plt.ylabel("Count")
plt.title("Counts of open and closed business")
plt.legend(title = "Open/Closed")
plt.show()

# %% [markdown]
# Next we take a look on how many business is still open or closed based on each main category. We can clearly see that `Restaurants` has the highest open and closed business of `36014` and `17872` respectively, followed by `Food` with `25712` open business and `8732` closed business. This can be explained as with higher number of business open, there will be a higher number of business closed due to competitiveness.

# %%
def count_open_closed(df):
  return df["is_open"].value_counts()

test_df = pd.DataFrame([count_open_closed(df) for df in new_category_df])

ratio_df = pd.DataFrame([((test_df[1][index]) / (test_df[1][index] + test_df[0][index])) for index, x in enumerate(category_list)])
ratio_df.index = category_list

ax = ratio_df.plot(kind="bar", stacked = False)

for container in ax.containers:
  ax.bar_label(container)

plt.gcf().set_size_inches(30, 10)
plt.xlabel("Categories")
plt.ylabel("Ratio")
plt.title("Ratio of open and closed business")
plt.show()

# %% [markdown]
# ## Question 4 Verdict
# It is difficult to conclude that the category of business affects whether it will remain open. Even though there is a high business count in one category, it will logically have a higher possibility for that category of business to close due to competitiveness, while having low business count will result in a higher possibility for that category of business to remain open. So it will be best to choose a business category where there is a balance in both the number of business in that category open and the possibility for that category to remain open when one is opening a business, like `Shopping` and `Home Services`.
