# %% [markdown]
# # Do open businesses have more reviews than closed businesses?

# %%
import pandas as pd
import seaborn as sb
sb.set_theme()

# %%
businesses = pd.read_json("../datasets/yelp_academic_dataset_business.json", lines=True)

# %%
businesses.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
sentiments = pd.read_csv("../datasets/reviews_id_with_sentiment.csv")

# %%
sentiments.head()
# Out:
#                 review_id             business_id sentiment_value
# 0  5teG7qQ0oxQNRhXTkTV-AA  Kfaq9cuyeXHkzWwL39jUWw        POSITIVE
# 1  yhJplqlngFVTFk5W_velmQ  9CRWWbw3iOo4-9FMAO6nKw        POSITIVE
# 2  Q90M8AHlNxUVL0ii7MAj1w  SJIQFKTW6uUsOo29w9IHxw        POSITIVE
# 3  FkuvWGHoqveIKmG2JjuEXg  gP_oWJykA2RocIs_GurKWQ        POSITIVE
# 4  P7zB0L55i7zwFt3vjAa8lw  gJSNa1bxwtY0dm1t-dh38w        NEGATIVE

# %%
positive_reviews = sentiments[sentiments["sentiment_value"] == "POSITIVE"]
negative_reviews = sentiments[sentiments["sentiment_value"] == "NEGATIVE"]

# %%
positive_review_counts = positive_reviews.groupby('business_id')['review_id'].count().rename("positive_review_counts")

# %%
negative_review_counts = negative_reviews.groupby('business_id')['review_id'].count().rename("negative_review_counts")

# %%
positive_review_counts
# Out:
# business_id
# ---kPU91CF4Lq2-WlRu9Lw    6
# --9osgUCSDUWUkoTLdvYhQ    2
# --O3ip9NpXTKD4oBS1pY2A    3
# --epgcb7xHGuJ-4PUeSLAw    1
# --hF_3v1JmU9nlu4zfXJ8Q    7
#                          ..
# zzQWjZ_1Dr7kkDYlk17qRw    2
# zzXDi0Pdv0s84M-oQaIa_g    4
# zzbZtgPYZS8sTIWQH6DwEw    1
# zziDpuuJw-Km1J4BaGpBKA    1
# zzjFdJwXuxBOGe9JeY_EMw    1
# Name: positive_review_counts, Length: 27741, dtype: int64

# %%
negative_review_counts
# Out:
# business_id
# --FcbSxK1AoEtEAxOgBaCw    1
# --N9yp3ZWqQIm7DqKRvorg    1
# --S43ruInmIsGrnnkmavRw    1
# --SJXpAa0E-GCp2smaHf0A    1
# --eBbs3HpZYIym5pEw8Qdw    1
#                          ..
# zymvTQ12tRy3bzmP4tPgOg    6
# zzIF9qp2UoHN48EeZH_IDg    1
# zzUxvYE-8Fj_dWqsPcagNg    1
# zzXRdzrVhfNWPHD2MeyWeA    1
# zzbZtgPYZS8sTIWQH6DwEw    1
# Name: negative_review_counts, Length: 21274, dtype: int64

# %%
businesses = pd.merge(businesses, negative_review_counts, on="business_id")
businesses = pd.merge(businesses, positive_review_counts, on="business_id")

# %%
businesses
# Out:
#                  business_id                                       name  \
# 0     ROeacJQwBeh05Rqg7F6TCg                                        BAP
# 1     kfNv-JZpuN6TVNSO6hHdkw                            Hibachi Express
# 2     9OG5YkX1g2GReZM0AskizA                    Romano's Macaroni Grill
# 3     aPNXGTDkf-4bjhyMBQxqpQ                                 Craft Hall
# 4     7PDi_iyik3jraDAzWwwR4Q  Chase JP Morgan Bank Credit Card Services
# ...                      ...                                        ...
# 9632  fWeWzB9STxcX40AgSEQVcw               Arizona-Sonora Desert Museum
# 9633  esBGrrmuZzSiECyRBoKvvA              Colony Grill - St. Petersburg
# 9634  wVxXRFf10zTTAs11nr4xeA                               PrimoHoagies
# 9635  AM7O0cwkxm6w_e0Q7-f9FQ                                  Starbucks
# 9636  w_4xUt-1AyY2ZwKtnjW0Xg                       Bittercreek Alehouse
#
#                  address            city state postal_code   latitude  \
# 0          1224 South St    Philadelphia    PA       19147  39.943223
# 1         6625 E 82nd St    Indianapolis    IN       46250  39.904320
# 2     5505 S Virginia St            Reno    NV       89502  39.476117
# 3     901 N Delaware Ave    Philadelphia    PA       19123  39.962582
# 4                             Wilmington    DE       19850  39.749361
# ...                  ...             ...   ...         ...        ...
# 9632    2021 N Kinney Rd          Tucson    AZ       85743  32.243733
# 9633     670 Central Ave  St. Petersburg    FL       33701  27.770872
# 9634      6024 Ridge Ave    Philadelphia    PA       19128  40.032483
# 9635        8817 S US-31    Indianapolis    IN       46227  39.638245
# 9636        246 N 8th St           Boise    ID       83702  43.616590
#
#        longitude  stars  review_count  is_open  \
# 0     -75.162568    4.5           205        1
# 1     -86.053080    4.0            20        1
# 2    -119.789339    2.5           339        1
# 3     -75.135657    3.5            65        1
# 4     -75.643331    1.5           111        1
# ...          ...    ...           ...      ...
# 9632 -111.166815    4.5           448        1
# 9633  -82.643069    4.5            38        1
# 9634  -75.214430    3.0            55        1
# 9635  -86.128069    4.0            29        1
# 9636 -116.202383    4.5           998        1
#
#                                              attributes  \
# 0     {'NoiseLevel': 'u'quiet'', 'GoodForMeal': '{'d...
# 1     {'RestaurantsDelivery': 'True', 'RestaurantsTa...
# 2     {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 3     {'OutdoorSeating': 'True', 'RestaurantsPriceRa...
# 4                                                  None
# ...                                                 ...
# 9632  {'GoodForKids': 'True', 'BusinessParking': '{'...
# 9633  {'RestaurantsPriceRange2': '2', 'RestaurantsAt...
# 9634  {'NoiseLevel': 'u'average'', 'RestaurantsTakeO...
# 9635  {'RestaurantsPriceRange2': '1', 'Caters': 'Fal...
# 9636  {'BikeParking': 'True', 'Alcohol': 'u'full_bar...
#
#                                              categories  \
# 0                                   Korean, Restaurants
# 1                Steakhouses, Asian Fusion, Restaurants
# 2                                  Restaurants, Italian
# 3     Eatertainment, Arts & Entertainment, Brewpubs,...
# 4             Banks & Credit Unions, Financial Services
# ...                                                 ...
# 9632  Parks, Zoos, Active Life, Botanical Gardens, M...
# 9633  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
# 9634  Restaurants, Specialty Food, Food, Sandwiches,...
# 9635                                 Food, Coffee & Tea
# 9636  Bars, Gastropubs, Sandwiches, Nightlife, Resta...
#
#                                                   hours  \
# 0     {'Monday': '11:30-20:30', 'Tuesday': '11:30-20...
# 1     {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 2     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 3     {'Monday': '0:0-0:0', 'Wednesday': '16:0-22:0'...
# 4                                                  None
# ...                                                 ...
# 9632  {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...
# 9633  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 9634  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 9635  {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...
# 9636  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
#
#       negative_review_counts  positive_review_counts
# 0                          1                       3
# 1                          1                       1
# 2                          6                       2
# 3                          2                       2
# 4                          4                       1
# ...                      ...                     ...
# 9632                       1                       6
# 9633                       2                      18
# 9634                       1                       1
# 9635                       1                       2
# 9636                       5                      14
#
# [9637 rows x 16 columns]

# %%
businesses["total_review_count"] = businesses["negative_review_counts"] + businesses["positive_review_counts"]

# %%
businesses.head()
# Out:
#               business_id                                       name  \
# 0  ROeacJQwBeh05Rqg7F6TCg                                        BAP
# 1  kfNv-JZpuN6TVNSO6hHdkw                            Hibachi Express
# 2  9OG5YkX1g2GReZM0AskizA                    Romano's Macaroni Grill
# 3  aPNXGTDkf-4bjhyMBQxqpQ                                 Craft Hall
# 4  7PDi_iyik3jraDAzWwwR4Q  Chase JP Morgan Bank Credit Card Services
#
#               address          city state postal_code   latitude   longitude  \
# 0       1224 South St  Philadelphia    PA       19147  39.943223  -75.162568
# 1      6625 E 82nd St  Indianapolis    IN       46250  39.904320  -86.053080
# 2  5505 S Virginia St          Reno    NV       89502  39.476117 -119.789339
# 3  901 N Delaware Ave  Philadelphia    PA       19123  39.962582  -75.135657
# 4                        Wilmington    DE       19850  39.749361  -75.643331
#
#    stars  review_count  is_open  \
# 0    4.5           205        1
# 1    4.0            20        1
# 2    2.5           339        1
# 3    3.5            65        1
# 4    1.5           111        1
#
#                                           attributes  \
# 0  {'NoiseLevel': 'u'quiet'', 'GoodForMeal': '{'d...
# 1  {'RestaurantsDelivery': 'True', 'RestaurantsTa...
# 2  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 3  {'OutdoorSeating': 'True', 'RestaurantsPriceRa...
# 4                                               None
#
#                                           categories  \
# 0                                Korean, Restaurants
# 1             Steakhouses, Asian Fusion, Restaurants
# 2                               Restaurants, Italian
# 3  Eatertainment, Arts & Entertainment, Brewpubs,...
# 4          Banks & Credit Unions, Financial Services
#
#                                                hours  negative_review_counts  \
# 0  {'Monday': '11:30-20:30', 'Tuesday': '11:30-20...                       1
# 1  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...                       1
# 2  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...                       6
# 3  {'Monday': '0:0-0:0', 'Wednesday': '16:0-22:0'...                       2
# 4                                               None                       4
#
#    positive_review_counts  total_review_count
# 0                       3                   4
# 1                       1                   2
# 2                       2                   8
# 3                       2                   4
# 4                       1                   5

# %% [markdown]
# It seems like the businesses that are closed have very few reviews compared to the open businesses, hence there is a correlation between number of reviews and the open state of the business

# %%
sb.boxplot(data=businesses, x=businesses["is_open"], y=businesses["total_review_count"])
# Out:
# <Axes: xlabel='is_open', ylabel='total_review_count'>

# %% [markdown]
# ## Verdict
# ### Do open businesses have more reviews than closed businesses?
# There is a relation between total number of reviews and whether a business is open.

# %% [markdown]
# ### Exporting to CSV

# %%
businesses
# Out:
#                  business_id                                       name  \
# 0     ROeacJQwBeh05Rqg7F6TCg                                        BAP
# 1     kfNv-JZpuN6TVNSO6hHdkw                            Hibachi Express
# 2     9OG5YkX1g2GReZM0AskizA                    Romano's Macaroni Grill
# 3     aPNXGTDkf-4bjhyMBQxqpQ                                 Craft Hall
# 4     7PDi_iyik3jraDAzWwwR4Q  Chase JP Morgan Bank Credit Card Services
# ...                      ...                                        ...
# 9632  fWeWzB9STxcX40AgSEQVcw               Arizona-Sonora Desert Museum
# 9633  esBGrrmuZzSiECyRBoKvvA              Colony Grill - St. Petersburg
# 9634  wVxXRFf10zTTAs11nr4xeA                               PrimoHoagies
# 9635  AM7O0cwkxm6w_e0Q7-f9FQ                                  Starbucks
# 9636  w_4xUt-1AyY2ZwKtnjW0Xg                       Bittercreek Alehouse
#
#                  address            city state postal_code   latitude  \
# 0          1224 South St    Philadelphia    PA       19147  39.943223
# 1         6625 E 82nd St    Indianapolis    IN       46250  39.904320
# 2     5505 S Virginia St            Reno    NV       89502  39.476117
# 3     901 N Delaware Ave    Philadelphia    PA       19123  39.962582
# 4                             Wilmington    DE       19850  39.749361
# ...                  ...             ...   ...         ...        ...
# 9632    2021 N Kinney Rd          Tucson    AZ       85743  32.243733
# 9633     670 Central Ave  St. Petersburg    FL       33701  27.770872
# 9634      6024 Ridge Ave    Philadelphia    PA       19128  40.032483
# 9635        8817 S US-31    Indianapolis    IN       46227  39.638245
# 9636        246 N 8th St           Boise    ID       83702  43.616590
#
#        longitude  stars  review_count  is_open  \
# 0     -75.162568    4.5           205        1
# 1     -86.053080    4.0            20        1
# 2    -119.789339    2.5           339        1
# 3     -75.135657    3.5            65        1
# 4     -75.643331    1.5           111        1
# ...          ...    ...           ...      ...
# 9632 -111.166815    4.5           448        1
# 9633  -82.643069    4.5            38        1
# 9634  -75.214430    3.0            55        1
# 9635  -86.128069    4.0            29        1
# 9636 -116.202383    4.5           998        1
#
#                                              attributes  \
# 0     {'NoiseLevel': 'u'quiet'', 'GoodForMeal': '{'d...
# 1     {'RestaurantsDelivery': 'True', 'RestaurantsTa...
# 2     {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 3     {'OutdoorSeating': 'True', 'RestaurantsPriceRa...
# 4                                                  None
# ...                                                 ...
# 9632  {'GoodForKids': 'True', 'BusinessParking': '{'...
# 9633  {'RestaurantsPriceRange2': '2', 'RestaurantsAt...
# 9634  {'NoiseLevel': 'u'average'', 'RestaurantsTakeO...
# 9635  {'RestaurantsPriceRange2': '1', 'Caters': 'Fal...
# 9636  {'BikeParking': 'True', 'Alcohol': 'u'full_bar...
#
#                                              categories  \
# 0                                   Korean, Restaurants
# 1                Steakhouses, Asian Fusion, Restaurants
# 2                                  Restaurants, Italian
# 3     Eatertainment, Arts & Entertainment, Brewpubs,...
# 4             Banks & Credit Unions, Financial Services
# ...                                                 ...
# 9632  Parks, Zoos, Active Life, Botanical Gardens, M...
# 9633  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
# 9634  Restaurants, Specialty Food, Food, Sandwiches,...
# 9635                                 Food, Coffee & Tea
# 9636  Bars, Gastropubs, Sandwiches, Nightlife, Resta...
#
#                                                   hours  \
# 0     {'Monday': '11:30-20:30', 'Tuesday': '11:30-20...
# 1     {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 2     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 3     {'Monday': '0:0-0:0', 'Wednesday': '16:0-22:0'...
# 4                                                  None
# ...                                                 ...
# 9632  {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...
# 9633  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 9634  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 9635  {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...
# 9636  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
#
#       negative_review_counts  positive_review_counts  total_review_count
# 0                          1                       3                   4
# 1                          1                       1                   2
# 2                          6                       2                   8
# 3                          2                       2                   4
# 4                          4                       1                   5
# ...                      ...                     ...                 ...
# 9632                       1                       6                   7
# 9633                       2                      18                  20
# 9634                       1                       1                   2
# 9635                       1                       2                   3
# 9636                       5                      14                  19
#
# [9637 rows x 17 columns]

# %%
businesses_with_total_review_count = businesses[["business_id" ,"total_review_count"]].copy()

# %%
businesses_with_total_review_count
# Out:
#                  business_id  total_review_count
# 0     ROeacJQwBeh05Rqg7F6TCg                   4
# 1     kfNv-JZpuN6TVNSO6hHdkw                   2
# 2     9OG5YkX1g2GReZM0AskizA                   8
# 3     aPNXGTDkf-4bjhyMBQxqpQ                   4
# 4     7PDi_iyik3jraDAzWwwR4Q                   5
# ...                      ...                 ...
# 9632  fWeWzB9STxcX40AgSEQVcw                   7
# 9633  esBGrrmuZzSiECyRBoKvvA                  20
# 9634  wVxXRFf10zTTAs11nr4xeA                   2
# 9635  AM7O0cwkxm6w_e0Q7-f9FQ                   3
# 9636  w_4xUt-1AyY2ZwKtnjW0Xg                  19
#
# [9637 rows x 2 columns]

# %%
businesses_with_total_review_count.to_csv("businesses_with_total_review_count.csv", index=False)
